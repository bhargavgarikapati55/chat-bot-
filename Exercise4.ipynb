# %% [markdown]
# <a href="https://colab.research.google.com/github/bhargavgarikapati55/chat-bot-/blob/main/Exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a="hello world"
c="   bhargav   "
print(a.split())
print(" ".join(a))
print(a.lower())
print(a.upper())
print(a.replace("h","hii"))
print(a.count("l"))
print(c.strip())
# Out:
# ['hello', 'world']
# h e l l o   w o r l d
# hello world
# HELLO WORLD
# hiiello world
# 3
# bhargav

# %%
b="bhargav"
print(a+b)
print(a*2)
print(a[3])
print(a[1:6])
print(a in a)
for i in a:
  print(a,end=" ")
# Out:
# hello worldbhargav
# hello worldhello world
# l
# ello
# True
# hello world hello world hello world hello world hello world hello world hello world hello world hello world hello world hello world

# %%
#functions in py

# %%
#number of vowels in given string
a=input().lower()
count=0
for i in range(len(a)):
  if(a[i] =='a'or a[i] =="e"or a[i]=='i'or a[i]=='o'or a[i]=='u'):
    count=count+1
print(count)
# Out:
# bhargav
# 2

# %%
#substring is present or not
a=input().lower()
b=input().lower()
index=a.find(b)
print(index)
# Out:
# hello world
# hello
# 0

# %%
#program that print reverse of given number
def revrse(num):
  sum=0
  while(num!=0):
    r=num%10
    sum=sum*10+r
    num=num//10
  return sum
print(revrse(int(input())))
# Out:
# 345
# 543
